# %%
import pandas as pd
import numpy  as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("Admission_Predict.csv")
df.head()
# Out:
#    Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0           1        337          118                  4  4.5   4.5  9.65
# 1           2        324          107                  4  4.0   4.5  8.87
# 2           3        316          104                  3  3.0   3.5  8.00
# 3           4        322          110                  3  3.5   2.5  8.67
# 4           5        314          103                  2  2.0   3.0  8.21
#
#    Research  Chance of Admit
# 0         1              0.92
# 1         1              0.76
# 2         1              0.72
# 3         1              0.80
# 4         0              0.65

# %% [markdown]
# # Analyze the Data

# %%
df.drop(['Serial No.'],axis=1,inplace=True)
df.head()
# Out:
#    GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  Research  \
# 0        337          118                  4  4.5   4.5  9.65         1
# 1        324          107                  4  4.0   4.5  8.87         1
# 2        316          104                  3  3.0   3.5  8.00         1
# 3        322          110                  3  3.5   2.5  8.67         1
# 4        314          103                  2  2.0   3.0  8.21         0
#
#    Chance of Admit
# 0              0.92
# 1              0.76
# 2              0.72
# 3              0.80
# 4              0.65

# %%
df.tail()
# Out:
#      GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  Research  \
# 395        324          110                  3  3.5   3.5  9.04         1
# 396        325          107                  3  3.0   3.5  9.11         1
# 397        330          116                  4  5.0   4.5  9.45         1
# 398        312          103                  3  3.5   4.0  8.78         0
# 399        333          117                  4  5.0   4.0  9.66         1
#
#      Chance of Admit
# 395              0.82
# 396              0.84
# 397              0.91
# 398              0.67
# 399              0.95

# %%
df.describe()
# Out:
#         GRE Score  TOEFL Score  University Rating         SOP        LOR   \
# count  400.000000   400.000000         400.000000  400.000000  400.000000
# mean   316.807500   107.410000           3.087500    3.400000    3.452500
# std     11.473646     6.069514           1.143728    1.006869    0.898478
# min    290.000000    92.000000           1.000000    1.000000    1.000000
# 25%    308.000000   103.000000           2.000000    2.500000    3.000000
# 50%    317.000000   107.000000           3.000000    3.500000    3.500000
# 75%    325.000000   112.000000           4.000000    4.000000    4.000000
# max    340.000000   120.000000           5.000000    5.000000    5.000000
#
#              CGPA    Research  Chance of Admit
# count  400.000000  400.000000        400.000000
# mean     8.598925    0.547500          0.724350
# std      0.596317    0.498362          0.142609
# min      6.800000    0.000000          0.340000
# 25%      8.170000    0.000000          0.640000
# 50%      8.610000    1.000000          0.730000
# 75%      9.062500    1.000000          0.830000
# max      9.920000    1.000000          0.970000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   GRE Score          400 non-null    int64
#  1   TOEFL Score        400 non-null    int64
#  2   University Rating  400 non-null    int64
#  3   SOP                400 non-null    float64
#  4   LOR                400 non-null    float64
#  5   CGPA               400 non-null    float64
#  6   Research           400 non-null    int64
#  7   Chance of Admit    400 non-null    float64
# dtypes: float64(4), int64(4)
# memory usage: 25.1 KB

# %%
df.shape
# Out:
# (400, 8)

# %%
df.columns
# Out:
# Index(['GRE Score', 'TOEFL Score', 'University Rating', 'SOP', 'LOR ', 'CGPA',
#        'Research', 'Chance of Admit '],
#       dtype='object')

# %%
df.dtypes
# Out:
# GRE Score              int64
# TOEFL Score            int64
# University Rating      int64
# SOP                  float64
# LOR                  float64
# CGPA                 float64
# Research               int64
# Chance of Admit      float64
# dtype: object

# %%
df.mean()
# Out:
# GRE Score            316.807500
# TOEFL Score          107.410000
# University Rating      3.087500
# SOP                    3.400000
# LOR                    3.452500
# CGPA                   8.598925
# Research               0.547500
# Chance of Admit        0.724350
# dtype: float64

# %%
df.median()
# Out:
# GRE Score            317.00
# TOEFL Score          107.00
# University Rating      3.00
# SOP                    3.50
# LOR                    3.50
# CGPA                   8.61
# Research               1.00
# Chance of Admit        0.73
# dtype: float64

# %%
df.mode()
# Out:
#    GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  Research  \
# 0        312        110.0                3.0  3.5   3.0   8.0       1.0
# 1        324          NaN                NaN  4.0   NaN   NaN       NaN
#
#    Chance of Admit
# 0              0.64
# 1               NaN

# %% [markdown]
# # Handling missing values

# %%
df.isnull().any()
# Out:
# GRE Score            False
# TOEFL Score          False
# University Rating    False
# SOP                  False
# LOR                  False
# CGPA                 False
# Research             False
# Chance of Admit      False
# dtype: bool

# %%
df.isnull().sum()
# Out:
# GRE Score            0
# TOEFL Score          0
# University Rating    0
# SOP                  0
# LOR                  0
# CGPA                 0
# Research             0
# Chance of Admit      0
# dtype: int64

# %% [markdown]
# # Data Visualization

# %% [markdown]
# ## Univariate Analysis

# %%
sns.displot(x=df["GRE Score"])
plt.title("GRE score distribution");

# %%
sns.displot(x=df["TOEFL Score"], color='orange')
plt.title("TOEFL score distribution");

# %%
sns.histplot(x=df.CGPA)
# Out:
# <AxesSubplot:xlabel='CGPA', ylabel='Count'>

# %%
sns.countplot(x=df["University Rating"]);
plt.title("Universities Star Rating by applicants");

# %%
sns.displot(x=df["SOP"], color='green');
plt.title("Distribution for ratings on SOP");

# %%
sns.displot(x=df["CGPA"], kde=True, color='black');
plt.title("Distribution of CGPA Score");

# %%
sns.countplot(x=df["Research"]);
plt.title("Research Count");

# %% [markdown]
# ## Bivariate Analysis

# %%
sns.regplot(x='SOP', y='CGPA', data=df)
# Out:
# <AxesSubplot:xlabel='SOP', ylabel='CGPA'>

# %%
sns.boxplot(x='SOP',y='CGPA',data=df)
# Out:
# <AxesSubplot:xlabel='SOP', ylabel='CGPA'>

# %%
sns.violinplot(x='SOP',y='CGPA',data=df)
# Out:
# <AxesSubplot:xlabel='SOP', ylabel='CGPA'>

# %%
sns.scatterplot(x='SOP', y='CGPA', data=df)
# Out:
# <AxesSubplot:xlabel='SOP', ylabel='CGPA'>

# %%
fig, ax = plt.subplots(figsize=(16,7))
sns.barplot(x=df.SOP,y=df.CGPA,ax=ax)
# Out:
# <AxesSubplot:xlabel='SOP', ylabel='CGPA'>

# %% [markdown]
# ## Multi-Variate Analysis

# %%
sns.pairplot(df,hue='Research')

# %%
corr_matrix = df.corr()
plt.figure(figsize = (15, 15))
sns.heatmap(corr_matrix,annot=True,fmt='0.2f')
plt.title("Correlation Matrix", fontsize = 25)
plt.show()

# %%
pd.plotting.scatter_matrix(df.loc[:,"GRE Score":"Research"],diagonal="kde",figsize=(20,15))
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.pairplot(data=df[['GRE Score', 'TOEFL Score', 'University Rating', 'SOP', 'LOR ', 'CGPA',
       'Research', 'Chance of Admit ']])

# %%
sns.pairplot(data=df[['GRE Score', 'TOEFL Score', 'University Rating', 'SOP', 'LOR ', 'CGPA',
       'Research', 'Chance of Admit ']],kind='kde')

# %% [markdown]
# # Independent Variable

# %%
x=df.iloc[:,:7]
x
# Out:
#      GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  Research
# 0          337          118                  4  4.5   4.5  9.65         1
# 1          324          107                  4  4.0   4.5  8.87         1
# 2          316          104                  3  3.0   3.5  8.00         1
# 3          322          110                  3  3.5   2.5  8.67         1
# 4          314          103                  2  2.0   3.0  8.21         0
# ..         ...          ...                ...  ...   ...   ...       ...
# 395        324          110                  3  3.5   3.5  9.04         1
# 396        325          107                  3  3.0   3.5  9.11         1
# 397        330          116                  4  5.0   4.5  9.45         1
# 398        312          103                  3  3.5   4.0  8.78         0
# 399        333          117                  4  5.0   4.0  9.66         1
#
# [400 rows x 7 columns]

# %% [markdown]
# # Dependent Variable

# %%
y=df.iloc[:,7:]
y
# Out:
#      Chance of Admit
# 0                0.92
# 1                0.76
# 2                0.72
# 3                0.80
# 4                0.65
# ..                ...
# 395              0.82
# 396              0.84
# 397              0.91
# 398              0.67
# 399              0.95
#
# [400 rows x 1 columns]

# %%
x.shape
# Out:
# (400, 7)

# %%
y.shape
# Out:
# (400, 1)

# %% [markdown]
# # Splitting The Data Into Train And Test

# %%
from sklearn.model_selection import train_test_split 
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)

# %%
x_train
# Out:
#      GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  Research
# 97         331          120                  3  4.0   4.0  8.96         1
# 27         298           98                  2  1.5   2.5  7.50         1
# 380        322          104                  3  3.5   4.0  8.84         1
# 230        313          104                  3  4.0   4.5  8.65         0
# 73         314          108                  4  4.5   4.0  9.04         1
# ..         ...          ...                ...  ...   ...   ...       ...
# 243        325          114                  3  3.5   3.0  9.04         1
# 152        321          112                  5  5.0   5.0  9.06         1
# 213        333          119                  5  5.0   4.5  9.78         1
# 93         301           97                  2  3.0   3.0  7.88         1
# 382        324          110                  4  4.5   4.0  9.15         1
#
# [320 rows x 7 columns]

# %%
y_train
# Out:
#      Chance of Admit
# 97               0.86
# 27               0.44
# 380              0.78
# 230              0.73
# 73               0.84
# ..                ...
# 243              0.76
# 152              0.86
# 213              0.96
# 93               0.44
# 382              0.82
#
# [320 rows x 1 columns]

# %%
x_test
# Out:
#      GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  Research
# 71         336          112                  5  5.0   5.0  9.76         1
# 122        310          106                  4  1.5   2.5  8.36         0
# 29         310           99                  2  1.5   2.0  7.30         0
# 399        333          117                  4  5.0   4.0  9.66         1
# 277        320          101                  2  2.5   3.0  8.62         0
# ..         ...          ...                ...  ...   ...   ...       ...
# 58         300           99                  1  3.0   2.0  6.80         1
# 377        290          100                  1  1.5   2.0  7.56         0
# 250        320          104                  3  3.0   2.5  8.57         1
# 354        297           98                  2  2.5   3.0  7.67         0
# 149        311          106                  2  3.5   3.0  8.26         1
#
# [80 rows x 7 columns]

# %%
y_test
# Out:
#      Chance of Admit
# 71               0.96
# 122              0.57
# 29               0.54
# 399              0.95
# 277              0.70
# ..                ...
# 58               0.36
# 377              0.47
# 250              0.74
# 354              0.59
# 149              0.79
#
# [80 rows x 1 columns]

# %%
x_train.shape
# Out:
# (320, 7)

# %%
x_test.shape
# Out:
# (80, 7)

# %%
y_train.shape
# Out:
# (320, 1)

# %%
y_test.shape
# Out:
# (80, 1)

# %% [markdown]
# # Model Evaluation

# %%
from sklearn.ensemble import GradientBoostingRegressor
model = GradientBoostingRegressor()
model.fit(x_train,y_train)
# Out:
# C:\Users\sarav\anaconda3\lib\site-packages\sklearn\ensemble\_gb.py:494: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# GradientBoostingRegressor()

# %%
model.score(x_test,y_test)
# Out:
# 0.7184188035276413

# %%
y_predict=model.predict(x_test)

# %%
from sklearn.metrics import mean_squared_error, r2_score,mean_absolute_error
import numpy as np
print('Mean Absolute Error:', mean_absolute_error(y_test, y_predict))  
print('Mean Squared Error:', mean_squared_error(y_test, y_predict))  
print('Root Mean Squared Error:', np.sqrt(mean_squared_error(y_test, y_predict)))
# Out:
# Mean Absolute Error: 0.05626343378126471
# Mean Squared Error: 0.005691530328996669
# Root Mean Squared Error: 0.07544223173393447

# %%
y_train = (y_train>0.5)
y_test = (y_test>0.5)

# %%
from sklearn.linear_model._logistic import LogisticRegression

lore = LogisticRegression(random_state=0, max_iter=1000)
lr = lore.fit(x_train, y_train)
# Out:
# C:\Users\sarav\anaconda3\lib\site-packages\sklearn\utils\validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
y_pred = lr.predict(x_test)

# %%
y_pred
# Out:
# array([ True,  True, False,  True,  True,  True,  True, False,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True, False,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True, False,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True, False, False,  True,  True,  True])

# %%
from sklearn.metrics import accuracy_score, recall_score, roc_auc_score, confusion_matrix

print('Accuracy Score: %f' %(accuracy_score(y_test, y_pred) * 100))  
print('Recall Score: %f' %(recall_score(y_test, y_pred) * 100))  
print('ROC AUC Score: %f' %(roc_auc_score(y_test, y_pred) * 100))
print('Confussion Matrix:\n', confusion_matrix(y_test, y_pred))
# Out:
# Accuracy Score: 91.250000
# Recall Score: 95.890411
# ROC AUC Score: 69.373777
# Confussion Matrix:
#  [[ 3  4]
#  [ 3 70]]

# %%
import pickle
pickle.dump(lr,open('university.pkl','wb'))
model=pickle.load(open('university.pkl','rb'))

# %%
model.predict([[323,108,3,3.5,3,8.6,0]])
# Out:
# C:\Users\sarav\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array([ True])
